# %%
import math
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import lxml

# %%
# 0. Cargar los datos de estatura y peso
url = 'http://wiki.stat.ucla.edu/socr/index.php?title=SOCR_Data_Dinov_020108_HeightsWeights&oldid=12529'

height_weight_df = pd.read_html(url)[1][['Height(Inches)','Weight(Pounds)']]

# %%
# 1. Count records in the dataframe
# 2. Crear una regresion lineal con estatura como variable explicatoria y peso como variable explicada
# 3. Hallar el intercepto
# 4. Hacer la grafica
# 5. Hallar correlacion y valor p
# 6. Interpretar el valor p.

# %% [markdown]
# # 1. Count records in the dataframe

# %%
record_count = height_weight_df.shape[0]
print(f'Number of records: {record_count}')
# Out:
# Number of records: 200

# %% [markdown]
# # 2. Crear una regresion lineal con estatura como variable explicatoria y peso

# %%
reg = linear_model.LinearRegression()
X = height_weight_df[['Height(Inches)']]
y = height_weight_df['Weight(Pounds)']
reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# # Intercept

# %%
intercept = reg.intercept_
print(f'Intercept: {intercept}')
# Out:
# Intercept: -106.02770644878126

# %% [markdown]
# # Hacer la grafica

# %%
plt.scatter(X, y, color='blue')
plt.plot(X, reg.predict(X), color='red', linewidth=2)
plt.xlabel('Height (Inches)')
plt.ylabel('Weight (Pounds)')
plt.title('Height vs Weight with Linear Regression Line')
plt.show()

# %% [markdown]
# # 5. Hallar correlacion y valor p

# %%
correlation, p_value = pearsonr(height_weight_df['Height(Inches)'], height_weight_df['Weight(Pounds)'])
print(f'Correlation: {correlation}')
print(f'p-value: {p_value}')
# Out:
# Correlation: 0.5568647346122995
# p-value: 1.1029015151265877e-17

# %% [markdown]
# # 6. Interpretar el valor p.

# %% [markdown]
# El valor p al ser un valor pequeño se puede concluir que si existe una relacion significativa entre las dos variables que son altura y peso.
